# %%
import random, sys, time

sequence_length = 50

def generate_random_dna_sequence(length):
    dna_bases = ['A', 'T', 'C', 'G']
    start_sequence = 'TAC'  # Start codon
    stop_sequences = ['ATT', 'ATC', 'ACT']
    random_stop_sequence = random.choice(stop_sequences)
    
    random_sequence = ''.join(random.choice(dna_bases) for _ in range(length-6))
    seq =  start_sequence + random_sequence + random_stop_sequence
    
    DNA_sequence_complete = [['' for _ in range(2)] for _ in range(sequence_length)]
    conversion_dict1 = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}
    i = 0
    for base in seq:
        opp_base = conversion_dict1[base]
        DNA_sequence_complete[i][0] = base
        DNA_sequence_complete[i][1] = opp_base
        i+=1
    return DNA_sequence_complete


DNA_sequence_complete = generate_random_dna_sequence(sequence_length)
#print("DNA Sequence Complete:", DNA_sequence_complete)
column = [row[0] for row in DNA_sequence_complete]
DNA_sequence = ''.join(column)
#print(DNA_sequence)

def animation_complete(DNA_sequence_complete,PAUSE = 0.15):
    ROWS = [
         '         ##',  # Index 0 has no {}.
         '        #{}-{}#',
         '       #{}---{}#',
         '      #{}-----{}#',
         '     #{}------{}#',
         '    #{}------{}#',
         '    #{}-----{}#',
         '     #{}---{}#',
         '     #{}-{}#',
         '      ##',  # Index 9 has no {}.
         '     #{}-{}#',
         '     #{}---{}#',
         '    #{}-----{}#',
         '    #{}------{}#',
         '     #{}------{}#',
         '      #{}-----{}#',
         '       #{}---{}#',
         '        #{}-{}#']
    time.sleep(2)
    rowIndex = 0

    for row_index, row in enumerate(DNA_sequence_complete):
        rowIndex = rowIndex + 1
        if rowIndex == len(ROWS):
            rowIndex = 0
        # Row indexes 0 and 9 don't have nucleotides:
        if rowIndex == 0 or rowIndex == 9:
            print(ROWS[rowIndex])
            continue

        leftNucleotide, rightNucleotide = row[0], row[1]

        print(ROWS[rowIndex].format(leftNucleotide, rightNucleotide))
        time.sleep(PAUSE)  # Add a slight pause.
        
def animation_partial(DNA_sequence,PAUSE = 0.15):
    ROWS = [
         '        #{}',
         '       #{}',
         '      #{}',
         '     #{}',
         '    #{}',
         '    #{}',
         '     #{}',
         '      #{}',
         '        {}#',
         '         {}#',
         '          {}#',
         '           {}#',
         '            {}#',
         '           {}#',
         '          {}#',
         '         {}#']
    time.sleep(2)
    rowIndex = 0

    for row_index, row in enumerate(DNA_sequence):
        rowIndex = rowIndex + 1
        if rowIndex == len(ROWS):
            rowIndex = 0
            continue

        leftNucleotide = row

        print(ROWS[rowIndex].format(leftNucleotide))
        time.sleep(PAUSE)  # Add a slight pause.
        
animation_complete(DNA_sequence_complete,PAUSE = 0.15)
animation_partial(DNA_sequence,PAUSE = 0.15)
# Out:
#         #T-A#
#        #A---T#
#       #C-----G#
#      #T------A#
#     #G------C#
#     #T-----A#
#      #C---G#
#      #G-C#
#       ##
#      #G-C#
#      #C---G#
#     #A-----T#
#     #A------T#
#      #C------G#
#       #C-----G#
#        #G---C#
#         #C-G#
#          ##
#         #T-A#
#        #G---C#
#       #A-----T#
#      #A------T#
#     #A------T#
#     #A-----T#
#      #G---C#
#      #C-G#
#       ##
#      #G-C#
#      #G---C#
#     #G-----C#
#     #T------A#
#      #A------T#
#       #A-----T#
#        #T---A#
#         #T-A#
#          ##
#         #A-T#
#        #A---T#
#       #A-----T#
#      #G------C#
#     #A------T#
#     #C-----G#
#      #C---G#
#      #C-G#
#       ##
#      #C-G#
#      #A---T#
#     #A-----T#
#     #C------G#
#      #T------A#
#        #T
#       #A
#      #C
#     #T
#     #G
#      #T
#       #C
#         G#
#          A#
#           G#
#            C#
#             A#
#            A#
#           C#
#          C#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 98
#      95         time.sleep(PAUSE)  # Add a slight pause.
#      97 animation_complete(DNA_sequence_complete,PAUSE = 0.15)
# ---> 98 animation_partial(DNA_sequence,PAUSE = 0.15)
#
# Cell In[19], line 94, in animation_partial(DNA_sequence, PAUSE)
#      90 rowIndex = rowIndex + 1
#      92 leftNucleotide = row
# ---> 94 print(ROWS[rowIndex].format(leftNucleotide))
#      95 time.sleep(PAUSE)
#
# IndexError: list index out of range

# %%
#T-A#
       #A---T#
      #C-----G#
     #T------A#
    #G------C#
    #T-----A#
     #C---G#
     #G-C#
      ##
     #G-C#
     #C---G#
    #A-----T#
    #A------T#
     #C------G#
      #C-----G#
       #G---C#
        #C-G#
        
        #T
      #A
     #C
    #T
    #G
     #T
      #C
        G#
         A#
          G#
           C#
            A#
           A#
          C#
         C#
